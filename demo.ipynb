# %%
import drone_simulation as sim
import matplotlib.pyplot as plt

sim_test = sim.DroneSimulator()
sim_test.run_simulation(10.0) 
sim_test.make_plot()
plt.show()
# Out:
# number of controller steps per simulation step: 1
# number of dynamics model steps per controller step: 2
