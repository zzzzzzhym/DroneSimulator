# %%
import simulation.manager
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 9]
sim_test = simulation.manager.Manager()
sim_test.set_up()
sim_test.run(12) 
sim_test.plot()
plt.show()
# Out:
# [PropellerLookupTable] Reading data from inflow_model\lookup_table\apc_8x6.yaml
# number of controller steps per simulation step: 1
# number of dynamics model steps per controller step: 2
