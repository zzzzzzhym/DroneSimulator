# %% [markdown]
# The following example shows how to log data for training. The log data will be saved into data/training folder

# %%
import matplotlib.pyplot as plt

import simulation.simulator as simulator
import simulation.sim_logger as sim_logger

sim_test = simulator.Engine()
sim_test.run_simulation(2)
sim_logger.log_sim_result(sim_test, "test_sample.csv")  
sim_test.make_plots()  
plt.show()
# Out:
# number of controller steps per simulation step: 1
# number of dynamics model steps per controller step: 2
# [PropellerLookupTable] Reading data from inflow_model\lookup_table\apc_8x6.yaml
# Sim data is written into:
# c:\YimingVirtualDDrive\7_workSpace\repo\neural-fly\Simulation\data\training\test_sample.csv
