# %% [markdown]
# Flight map finds the atomic trajectory from data/map folder and integrate them into a flight map. If is_random is False, the flight map picks the subtrajectory according to the order of the ID. The ID corresponds to the index of the atomic trajectory file in the file system. is_random being False is useful in debug especially when result replication is needed.

# %%
import matplotlib.pyplot as plt
import os
import sys

# Get the current directory of the notebook
notebook_dir = os.getcwd()

# Add the parent directory to sys.path
parent_dir = os.path.abspath(os.path.join(notebook_dir, '..'))
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

import flight_map
trajectory: flight_map.FlightMap = flight_map.construct_map_with_subtrajs(is_random=False, subtraj_id=[0, 1])
trajectory.plot_stitched_traj()

# %% [markdown]
# On the other hand, to generate shuffled trajectory, one can also set is_random to True to get some randomly selected trajectory.

# %%
import flight_map
trajectory: flight_map.FlightMap = flight_map.construct_map_with_subtrajs(is_random=True, num_of_subtrajs=50)
trajectory.plot_stitched_traj()

# %% [markdown]
# One can also set limits to the space in order to confine the trajectory in certain area. This module currently makes a naive implemtation simply checking the end points of the atomic trajectories to see if they are out of bound. However, this does not guarantee the whole trajectory is inside the confine space. So the actual limit need to be determined later after stitching.

# %%
# %matplotlib tk
import flight_map
x_lim = 0.5 # -x_lim to x_lim
y_lim = 8.0 # -y_lim to y_lim
# z_lim is left free

trajectory: flight_map.FlightMap = flight_map.construct_map_with_subtrajs(is_random=False, num_of_subtrajs=200, subtraj_id=list(range(200)), x_limit=x_lim, y_limit=y_lim)
print("total time = ", trajectory.total_time)
trajectory.plot_stitched_traj()
# Out:
# total time =  170.0

# %% [markdown]
# Make a figure 8 route.

# %%
import flight_map

trajectory: flight_map.FlightMap = flight_map.construct_map_with_specific_subtrajs(["figure_8.pkl"]*20)
print("total time = ", trajectory.total_time)
trajectory.plot_stitched_traj()
# Out:
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# total time =  125.60000000000001
